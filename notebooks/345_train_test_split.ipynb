# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Split similar name pairs into train (frequent) and test (rare)
#
# Take the similar pairs generated by notebook 40, remove bad pairs identified by Clorinda, and split into train and test. Train contains only rows where both the tree name and the record name are among the most frequent tree preferred names. The assumption is that more-frequent names will have more-reliable tree-record attachment frequencies for training purposes.

# %%
from collections import Counter

import pandas as pd

from nama.data.filesystem import download_file_from_s3, save_file

# %%
# TODO run for given and surname
given_surname = "given"
# given_surname = "surname"
sample_name = "john"
train_size = 0.45

in_path = f"s3://fs-nama-data/2024/familysearch-names/processed/tree-hr-{given_surname}-similar.csv.gz"
pref_path = f"s3://fs-nama-data/2024/familysearch-names/processed/tree-preferred-{given_surname}-aggr.csv.gz"
# re-use Clorinda's bad pairs from last year
bad_pairs_path=f"s3://fs-nama-data/2023/familysearch-names/interim/{given_surname}_variants_clorinda_reviewed.tsv"

train_path = f"s3://fs-nama-data/2024/familysearch-names/processed/tree-hr-{given_surname}-train.csv.gz"
test_path = f"s3://fs-nama-data/2024/familysearch-names/processed/tree-hr-{given_surname}-test.csv.gz"

# %% [markdown]
# ## Read similar name pairs

# %%
in_path = download_file_from_s3(in_path) if in_path.startswith("s3://") else in_path
df = pd.read_csv(in_path, na_filter=False)
print(df.shape)
df.head(3)
# Out:
# (4797249, 10)
#   name alt_name  frequency  reverse_frequency  sum_name_frequency  \
# 0    a        a    1622927            1622927             2578937
# 1   aa        a        139                154                 482
# 2   aa       aa         45                 45                 482
#
#    total_name_frequency  total_alt_name_frequency  ordered_prob  \
# 0              36295683                  36295683      0.629301
# 1                  5067                  36295683      0.288382
# 2                  5067                      5067      0.093361
#
#    unordered_prob  similarity
# 0        0.046807         1.0
# 1        0.000008         0.5
# 2        0.008961         1.0

# %%
# name = tree_name, alt_name = record_name
df = df[["name", "alt_name", "frequency"]]
df.rename(columns={"name": "tree_name", "alt_name": "record_name"}, inplace=True)
print(df.shape)
df.head(3)
# Out:
# (4797249, 3)
#   tree_name record_name  frequency
# 0         a           a    1622927
# 1        aa           a        139
# 2        aa          aa         45

# %% [markdown]
# ## Remove non-alpha names

# %%
alpha = r"[a-z]+"
df = df[(df["tree_name"].str.fullmatch(alpha)) & (df["record_name"].str.fullmatch(alpha))]
print(df.shape)
# Out:
# (4797249, 3)

# %% [markdown]
# ## Remove bad pairs

# %%
bad_pairs_path = download_file_from_s3(bad_pairs_path) if bad_pairs_path.startswith("s3://") else bad_pairs_path
bad_pairs_df = pd.read_csv(bad_pairs_path, 
                           na_filter=False,
                           sep='\t', 
                           names=["name1", "name2"])

# %%
print(bad_pairs_df.shape)
bad_pairs_df.head(3)
# Out:
# (19526, 2)
#     name1    name2
# 0    aage    angel
# 1    aage    angie
# 2  aaltje  adaline

# %%
# remove tree_name, record_name matches
df = pd.merge(df, bad_pairs_df, 
              left_on=['tree_name','record_name'],right_on=['name1','name2'],
              how='left', indicator=True)
df = df[df['_merge'] != 'both'].drop(columns=['name1', 'name2', '_merge'])
# remove record_name, tree_name matches
df = pd.merge(df, bad_pairs_df, 
              left_on=['tree_name','record_name'],right_on=['name2','name1'],
              how='left', indicator=True)
df = df[df['_merge'] != 'both'].drop(columns=['name1', 'name2', '_merge'])
print(df.shape)
df.head(20)
# Out:
# (4775571, 3)
#     tree_name record_name  frequency
# 0           a           a    1622927
# 1          aa           a        139
# 2          aa          aa         45
# 3          aa         aae          5
# 4          aa         ana         12
# 5          aa        anna         76
# 6      aaaard     aagaard         12
# 7      aaafke       aafke          6
# 8       aaage        aage          2
# 9       aaage         age          9
# 10     aaagot       aagot          8
# 11    aaaltje      aaltje          7
# 12    aaaltje     aaltjen          2
# 13     aaaron       aaron         34
# 14      aaart        aart         18
# 15  aaassiena    aassiena          2
# 16        aab         aab          7
# 17        aab         abb          2
# 18       aaba         aba          5
# 19       aabe        aabe          5

# %% [markdown]
# ## Read name frequencies

# %%
pref_path = download_file_from_s3(pref_path) if pref_path.startswith("s3://") else pref_path
print(pref_path)
pref_df = pd.read_csv(pref_path, na_filter=False)
# Out:
# /tmp/tmpol_vbars.gz
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In[10], line 3
#       1 pref_path = download_file_from_s3(pref_path) if pref_path.startswith("s3://") else pref_path
#       2 print(pref_path)
# ----> 3 pref_df = pd.read_csv(pref_path, na_filter=False)
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1679, in TextFileReader._make_engine(self, f, engine)
#    1676     raise ValueError(msg)
#    1678 try:
# -> 1679     return mapping[engine](f, **self.options)
#    1680 except Exception:
#    1681     if self.handles is not None:
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:550, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:639, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~/anaconda3/envs/nama/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:2021, in pandas._libs.parsers.raise_parser_error()
#
# File ~/anaconda3/envs/nama/lib/python3.9/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/anaconda3/envs/nama/lib/python3.9/gzip.py:487, in _GzipReader.read(self, size)
#     483 if self._new_member:
#     484     # If the _new_member flag is set, we have to
#     485     # jump to the next member, if there is one.
#     486     self._init_read()
# --> 487     if not self._read_gzip_header():
#     488         self._size = self._pos
#     489         return b""
#
# File ~/anaconda3/envs/nama/lib/python3.9/gzip.py:435, in _GzipReader._read_gzip_header(self)
#     432     return False
#     434 if magic != b'\037\213':
# --> 435     raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     437 (method, flag,
#     438  self._last_mtime) = struct.unpack("<BBIxx", self._read_exact(8))
#     439 if method != 8:
#
# BadGzipFile: Not a gzipped file (b'PA')

# %%
print(pref_df.shape)
pref_df.head(3)

# %% [markdown]
# ## Split based upon frequency as a preferred name

# %%
# map name -> frequency
name_frequency = pref_df.set_index(pref_df.columns[0]).to_dict()[pref_df.columns[1]]
name_frequency[sample_name]

# %%
# get frequency of all_names (tree or record) in df
counter = Counter()
for name in set(df["tree_name"]) | set(df["record_name"]):
    counter[name] = name_frequency.get(name, 0)
len(counter)

# %%
# what is the least most-common name?
size = int(train_size * len(counter))
print(size)
counter.most_common()[size-5:size+5]

# %%
df[(df["tree_name"] == "weober") | (df["record_name"] == "weober")]

# %%
# keep the top train_size as training names, put the rest in test
train_names = set(name for name, _ in counter.most_common(size))
len(train_names)

# %%
train_df = df[(df["tree_name"].isin(train_names)) & (df["record_name"].isin(train_names))]
train_df.shape

# %%
test_df = df[(~df["tree_name"].isin(train_names)) | (~df["record_name"].isin(train_names))]
test_df.shape

# %% [markdown]
# ## Write train and test

# %%
save_file(train_path,
          lambda local_out_path : train_df.to_csv(local_out_path, index=False))

# %%
save_file(test_path,
          lambda local_out_path : test_df.to_csv(local_out_path, index=False))
