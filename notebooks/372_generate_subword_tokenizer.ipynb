# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Generate subword tokenizer
#
# Use the tree-hr attachment names to train a subword tokenizer.

# %%
import random

import pandas as pd
from tokenizers import models, Tokenizer, trainers
from transformers import PreTrainedTokenizerFast
from tqdm.auto import tqdm

from nama.data.filesystem import download_file_from_s3, save_file

# %%
# TODO run both given and surname
given_surname = "given"
# given_surname = "surname"

# run with 256, 512, 1024, 1536, 2048
vocab_size = 1536

frequencies_path = f"s3://fs-nama-data/2024/familysearch-names/interim/tree-hr-{given_surname}-aggr-v2.parquet"

tokenizer_path=f"s3://fs-nama-data/2024/nama-data/data/models/fs-{given_surname}-subword-tokenizer-{vocab_size}.json"

# %% [markdown]
# ## Load data

# %%
# load counts
frequencies_path = download_file_from_s3(frequencies_path) if frequencies_path.startswith("s3://") else frequencies_path
counts_df = pd.read_parquet(frequencies_path)
print(counts_df.shape)
counts_df.head(3)
# Out:
# (25541154, 10)
#   name alt_name  frequency  reverse_frequency  sum_name_frequency  \
# 0    a        a    1622927            1622927             2578937
# 1    a       aa        154                139             2578937
# 2    a      aaa          3                  5             2578937
#
#    total_name_frequency  total_alt_name_frequency  ordered_prob  \
# 0              36295683                  36295683      0.629301
# 1              36295683                      5067      0.000060
# 2              36295683                       143      0.000001
#
#    unordered_prob  similarity
# 0    4.680698e-02    1.000000
# 1    8.071524e-06    0.500000
# 2    2.204111e-07    0.333333

# %%
# create a dataframe with alt name (record name) frequencies
counts_df = counts_df[['alt_name', 'total_alt_name_frequency']].drop_duplicates()
print(counts_df.shape)
counts_df.head(3)
# Out:
# (6148634, 2)
#   alt_name  total_alt_name_frequency
# 0        a                  36295683
# 1       aa                      5067
# 2      aaa                       143

# %%
counts_df['total_alt_name_frequency'].sum()
# Out:
# np.int64(2906726951)

# %%
# get list of all names (shuffle takes a long time)
all_names = []
for row in tqdm(counts_df.to_dict('records')):
    for _ in range(row['total_alt_name_frequency'] // 2):
        all_names.append(row['alt_name'])
random.shuffle(all_names)    
print(len(all_names))
# Out:
#   0%|          | 0/6148634 [00:00<?, ?it/s]
# 1451132858

# %% [markdown]
# ## Generate Subwords

# %%
special_tokens = ["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]

# %%
tokenizer = Tokenizer(models.WordPiece(unk_token="[UNK]"))

trainer = trainers.WordPieceTrainer(vocab_size=vocab_size, special_tokens=special_tokens)

# %%
# %%time
# train tokenizer from all names
def get_all_names_batch(batch_size=10000):
    for i in range(0, len(all_names), batch_size):
        yield all_names[i : i + batch_size]
        
tokenizer.train_from_iterator(get_all_names_batch(), 
                              trainer=trainer, 
                              length=len(all_names))
# Out:
# CPU times: user 1h 2min 42s, sys: 1h 36min 33s, total: 2h 39min 15s
# Wall time: 16min 55s

# %%
tokenizer.get_vocab()
# Out:
# {'##onnie': 1064,
#  'cathrine': 1407,
#  '##oo': 1418,
#  'timothy': 1495,
#  '##zia': 1507,
#  '##ler': 1122,
#  'p': 20,
#  'reb': 523,
#  '##v': 43,
#  'mar': 61,
#  'addie': 1040,
#  '##ina': 123,
#  '##res': 653,
#  'joannes': 794,
#  '##per': 837,
#  'cur': 1005,
#  'beatr': 693,
#  '##ven': 883,
#  '##ier': 835,
#  'caro': 349,
#  'caroline': 431,
#  '##um': 722,
#  'marjor': 832,
#  'ang': 515,
#  'lillie': 659,
#  '##art': 889,
#  'car': 190,
#  '##ona': 656,
#  '##dalupe': 1091,
#  'naom': 1399,
#  'joann': 586,
#  'dav': 256,
#  'bessie': 526,
#  'jona': 928,
#  'norma': 1189,
#  'fan': 652,
#  'ferdin': 1152,
#  'die': 1434,
#  '##ail': 1215,
#  'sophia': 609,
#  'wilbur': 996,
#  'anne': 354,
#  'robert': 154,
#  'qu': 1417,
#  'ma': 90,
#  'burton': 1521,
#  'joanna': 1243,
#  'mur': 948,
#  'winifred': 1202,
#  'warren': 801,
#  'david': 279,
#  'dor': 205,
#  'sof': 1259,
#  'kathryn': 1046,
#  'jan': 189,
#  'andre': 957,
#  'grace': 399,
#  'tim': 1298,
#  '##q': 52,
#  '##nis': 994,
#  'aaron': 1309,
#  '##ur': 121,
#  '##ima': 1366,
#  '##old': 271,
#  'irene': 493,
#  'urs': 1425,
#  'alta': 1431,
#  '##gie': 625,
#  'tom': 971,
#  'hulda': 1513,
#  'jeff': 992,
#  'howard': 477,
#  '##ram': 1289,
#  'eva': 424,
#  'stan': 650,
#  'cli': 594,
#  'am': 344,
#  'emi': 1062,
#  'austin': 1344,
#  'fay': 878,
#  '##iz': 1188,
#  'susan': 414,
#  '##vie': 874,
#  'wilhelmina': 979,
#  '##tie': 1524,
#  'peter': 355,
#  'n': 18,
#  'katie': 916,
#  'bet': 1095,
#  '##je': 595,
#  'leroy': 684,
#  'levi': 1183,
#  '##arl': 93,
#  'nicolas': 1457,
#  '##ileen': 1534,
#  'dennis': 1129,
#  '##ar': 57,
#  'friedrich': 563,
#  'freder': 254,
#  'lee': 325,
#  '##abel': 1223,
#  'bas': 1416,
#  'elmer': 580,
#  '##lio': 919,
#  'sadie': 1051,
#  'ing': 1236,
#  '##ine': 104,
#  'vic': 418,
#  'josef': 482,
#  '##ga': 932,
#  '##nez': 1118,
#  'delia': 1361,
#  'benjam': 381,
#  '##rence': 540,
#  '##oyd': 433,
#  'ele': 551,
#  'catharina': 378,
#  'oli': 492,
#  'bruce': 1270,
#  'mir': 1346,
#  '##dison': 1363,
#  'grover': 1390,
#  '##lene': 1192,
#  '##val': 1450,
#  'merle': 1511,
#  'hul': 1378,
#  'ros': 386,
#  'mabel': 499,
#  'ge': 110,
#  'ed': 122,
#  'percy': 1244,
#  '##ach': 1023,
#  'vera': 937,
#  'washington': 858,
#  '##la': 94,
#  'den': 831,
#  '##im': 310,
#  'julian': 826,
#  'willie': 593,
#  '##r': 48,
#  'augustus': 969,
#  'henry': 149,
#  '##lace': 927,
#  'ale': 392,
#  '##ario': 1045,
#  'nettie': 906,
#  'bob': 1171,
#  'o': 19,
#  'pa': 181,
#  '##qu': 434,
#  'nic': 649,
#  'arthur': 252,
#  'belle': 613,
#  'max': 664,
#  'kath': 227,
#  'minnie': 385,
#  '##ias': 683,
#  '##eli': 312,
#  'alvin': 851,
#  'ver': 336,
#  'adam': 759,
#  '##ott': 817,
#  'cath': 158,
#  '##ula': 547,
#  'joa': 618,
#  '##land': 778,
#  '##mond': 343,
#  'pe': 403,
#  'joaqu': 880,
#  'violet': 981,
#  'raf': 1063,
#  'd': 8,
#  'dorth': 1293,
#  '##o': 37,
#  'johann': 226,
#  'dora': 700,
#  '##iola': 707,
#  'ira': 939,
#  'sher': 1127,
#  'alberta': 1436,
#  'adr': 1133,
#  'viv': 1101,
#  '##asta': 1341,
#  'patrick': 775,
#  '##rad': 758,
#  '##elina': 933,
#  '##ira': 961,
#  'ollie': 1239,
#  's': 23,
#  '##vey': 634,
#  'margarita': 1477,
#  '##ire': 1112,
#  '##ston': 1460,
#  'petra': 1492,
#  'em': 160,
#  'angel': 1353,
#  'byron': 1473,
#  '##ud': 391,
#  '##ella': 255,
#  'edgar': 764,
#  '##ville': 915,
#  'for': 1254,
#  '##ay': 176,
#  'doris': 702,
#  'charley': 1394,
#  'fl': 199,
#  '##ard': 102,
#  '##do': 737,
#  '##idad': 1194,
#  '##ich': 138,
#  '##umb': 1535,
#  'henrietta': 922,
#  'lew': 458,
#  'hilda': 1007,
#  '##ett': 232,
#  '##nest': 357,
#  'br': 590,
#  '##org': 109,
#  '##roe': 1138,
#  'glen': 591,
#  'rand': 1292,
#  '##ra': 153,
#  'kathleen': 1156,
#  'hiram': 1157,
#  '##iley': 1381,
#  'mat': 374,
#  'marguer': 806,
#  'law': 506,
#  '##ris': 150,
#  'doroth': 274,
#  'wash': 838,
#  'clarence': 384,
#  '##h': 34,
#  '##b': 49,
#  '##len': 212,
#  '##lina': 435,
#  'mildred': 453,
#  'is': 318,
#  '##line': 193,
#  '##iana': 599,
#  '##y': 53,
#  'char': 736,
#  'si': 748,
#  '##bert': 101,
#  'mil': 258,
#  '##etta': 484,
#  '##ca': 323,
#  'rita': 1050,
#  '##ield': 1054,
#  'phyllis': 1235,
#  'anders': 1395,
#  'vicente': 1486,
#  'joan': 809,
#  '##in': 64,
#  'emilie': 1376,
#  'friederike': 1147,
#  'w': 27,
#  'frances': 270,
#  '##ch': 249,
#  'katharina': 630,
#  'carol': 857,
#  'catharine': 582,
#  'elizabeth': 155,
#  'paul': 348,
#  '##d': 45,
#  'rachel': 819,
#  '##don': 918,
#  'gustav': 1198,
#  '##g': 56,
#  '##as': 194,
#  'dan': 331,
#  'christina': 584,
#  'matilda': 698,
#  'g': 11,
#  'dol': 717,
#  'julius': 895,
#  '##ettie': 699,
#  'warr': 796,
#  'a': 5,
#  'gord': 896,
#  '##ulah': 936,
#  'gott': 955,
#  'ken': 521,
#  '##ash': 811,
#  'fern': 1052,
#  '##et': 81,
#  'do': 696,
#  'pol': 1136,
#  '##riel': 1379,
#  'lam': 1385,
#  'estelle': 1424,
#  '##om': 222,
#  'lillian': 445,
#  'clin': 1069,
#  'viola': 720,
#  '##ey': 231,
#  '##ot': 428,
#  '##atr': 575,
#  'josefa': 685,
#  '##eline': 840,
#  '##ara': 126,
#  'maud': 731,
#  '##ida': 565,
#  '##deline': 842,
#  '##te': 142,
#  'john': 84,
#  'clara': 346,
#  '##ee': 861,
#  'etta': 987,
#  'lena': 642,
#  'con': 511,
#  '##on': 72,
#  'cly': 686,
#  'cas': 740,
#  '##ffie': 870,
#  'cecil': 814,
#  '##inia': 416,
#  'rh': 1111,
#  'vicen': 1150,
#  '##well': 863,
#  '##by': 457,
#  'felix': 1163,
#  '##t': 33,
#  '##j': 47,
#  'daniel': 380,
#  '##ir': 180,
#  '##tor': 456,
#  'cec': 560,
#  '##ke': 741,
#  '##ilde': 1145,
#  'sebast': 1193,
#  'lola': 1257,
#  '##wen': 1288,
#  'audr': 1360,
#  '##uer': 788,
#  'phoebe': 1367,
#  '##ord': 309,
#  'rosalia': 1483,
#  '##sia': 1517,
#  'jack': 496,
#  '##th': 63,
#  'anto': 1057,
#  'johanne': 1107,
#  '##k': 50,
#  'ernst': 1497,
#  'hora': 869,
#  'george': 125,
#  'ernest': 397,
#  '##ve': 440,
#  'gu': 497,
#  'clyde': 703,
#  'les': 784,
#  'thelma': 828,
#  'effie': 897,
#  'della': 967,
#  'will': 640,
#  'georgia': 1030,
#  'hattie': 637,
#  'clem': 1068,
#  'reuben': 1267,
#  'lorraine': 1374,
#  '##ena': 221,
#  'pierre': 1386,
#  '##ic': 79,
#  'al': 108,
#  '##ua': 1328,
#  '##bur': 716,
#  '##field': 1154,
#  'barb': 367,
#  'doming': 1260,
#  '##lan': 489,
#  'gi': 1264,
#  'eli': 107,
#  'just': 1323,
#  'sp': 1501,
#  'eula': 1294,
#  '##riet': 335,
#  '##to': 633,
#  '##onzo': 1076,
#  '##cen': 1271,
#  '##mo': 1026,
#  '##ala': 1275,
#  'mo': 1384,
#  '##son': 219,
#  'ka': 627,
#  'ly': 483,
#  'ce': 1140,
#  'karo': 1087,
#  'dewey': 1393,
#  'lloyd': 773,
#  '##ance': 876,
#  'jerome': 1412,
#  'scott': 1447,
#  'theresia': 1262,
#  'clifford': 767,
#  'myrtle': 556,
#  'mad': 1035,
#  '##ew': 225,
#  'frie': 316,
#  'anna': 143,
#  '##wood': 1029,
#  'otis': 1445,
#  'michael': 412,
#  'margr': 691,
#  'ruf': 1074,
#  'cecelia': 1490,
#  'pier': 1092,
#  'sy': 1131,
#  '##oth': 243,
#  '##ice': 301,
#  '##al': 83,
#  'dean': 1148,
#  'blanche': 694,
#  '##den': 968,
#  'newton': 1209,
#  'bar': 277,
#  'ste': 429,
#  'marsh': 1086,
#  '##lino': 1408,
#  '##eus': 1487,
#  'isabel': 792,
#  '##po': 1272,
#  '##vel': 1520,
#  'en': 755,
#  'florence': 321,
#  'hein': 614,
#  'eugen': 1130,
#  '##upe': 1078,
#  '##em': 783,
#  'e': 9,
#  'vinc': 930,
#  '##ze': 984,
#  'lula': 839,
#  'er': 235,
#  'ber': 207,
#  '##thia': 1349,
#  'ul': 1466,
#  'matth': 770,
#  '##olph': 596,
#  'nora': 789,
#  'martin': 436,
#  'melvin': 845,
#  '##cion': 893,
#  'lucy': 491,
#  'charlie': 834,
#  'teresa': 901,
#  'kir': 934,
#  'll': 754,
#  'emm': 1094,
#  'amos': 1221,
#  'lewis': 474,
#  '##ius': 557,
#  'reg': 820,
#  'beulah': 1044,
#  'mos': 1280,
#  'juliana': 1316,
#  '##man': 200,
#  'opal': 1269,
#  'kenneth': 576,
#  'ern': 1453,
#  'wel': 1485,
#  'cand': 1499,
#  'charl': 118,
#  '##p': 46,
#  '##ford': 610,
#  '##vi': 671,
#  'fran': 96,
#  'maurice': 1121,
#  '##il': 66,
#  '##sa': 202,
#  'francisc': 1331,
#  '##sie': 201,
#  'magdalene': 1464,
#  'per': 518,
#  'douglas': 1053,
#  'bever': 1527,
#  'margar': 148,
#  '##re': 712,
#  'adel': 1452,
#  'karl': 749,
#  'liz': 669,
#  '##ington': 803,
#  '##gna': 679,
#  '##ath': 117,
#  '##hel': 280,
#  '##ik': 315,
#  'patric': 908,
#  'nellie': 479,
#  '##omer': 829,
#  '##ma': 98,
#  '##elyn': 583,
#  '##co': 360,
#  'joy': 1019,
#  'joao': 1060,
#  'antonio': 504,
#  '##ola': 432,
#  'sus': 264,
#  'ch': 88,
#  'f': 10,
#  'bernard': 564,
#  'ben': 238,
#  'helen': 269,
#  'luis': 628,
#  '##ro': 322,
#  'lar': 860,
#  'm': 17,
#  '##e': 40,
#  'leona': 892,
#  '##i': 31,
#  'horace': 921,
#  'merce': 1312,
#  'luella': 1369,
#  '##ward': 173,
#  '##ed': 105,
#  'cora': 566,
#  'elisabetha': 636,
#  '##cia': 611,
#  '##entin': 1389,
#  'georg': 114,
#  'sara': 169,
#  'susie': 1116,
#  '##the': 1444,
#  'maggie': 674,
#  'je': 273,
#  'bertha': 425,
#  'herman': 544,
#  'shir': 911,
#  'v': 26,
#  '##os': 286,
#  '##vira': 1448,
#  '##sh': 648,
#  '##irg': 329,
#  'cor': 448,
#  'joh': 78,
#  '##eland': 1043,
#  'raymond': 395,
#  'charlot': 538,
#  '##ery': 1186,
#  '##itt': 1201,
#  'nan': 352,
#  'elsie': 622,
#  'na': 744,
#  '##ker': 1047,
#  'r': 22,
#  '##ino': 743,
#  'benjamin': 390,
#  '##ick': 197,
#  'hannah': 598,
#  '##l': 32,
#  'jak': 623,
#  'nath': 766,
#  '##las': 797,
#  'se': 907,
#  'morris': 1120,
#  'ke': 1214,
#  '##oll': 1233,
#  'cla': 361,
#  '##ge': 746,
#  '##ores': 635,
#  'du': 1469,
#  'mollie': 1178,
#  'lucia': 1514,
#  'leo': 589,
#  '##arina': 266,
#  '##ton': 140,
#  'william': 86,
#  'wil': 76,
#  'philip': 514,
#  'fred': 164,
#  '##din': 1105,
#  'jasper': 1423,
#  'linda': 1530,
#  'adela': 1032,
#  '##than': 1191,
#  'nathaniel': 1322,
#  'sarah': 177,
#  'andrew': 400,
#  'nancy': 427,
#  'leslie': 846,
#  'te': 1085,
#  'theod': 527,
#  'loren': 859,
#  'esther': 574,
#  'karen': 1403,
#  'joyce': 1185,
#  '##ia': 75,
#  'cal': 632,
#  'corne': 646,
#  '##cio': 695,
#  'igna': 871,
#  'mae': 332,
#  'hazel': 553,
#  'eleanor': 728,
#  'hugh': 807,
#  'este': 1321,
#  'ir': 330,
#  'ramon': 1232,
#  '##uz': 1354,
#  'lydia': 654,
#  'ro': 95,
#  'magdal': 536,
#  'an': 74,
#  '##ilia': 667,
#  'leon': 294,
#  'viol': 920,
#  'mary': 87,
#  'ane': 1004,
#  'harry': 290,
#  '##jes': 1038,
#  'pearl': 494,
#  '##ane': 1250,
#  'baptis': 1391,
#  '##ita': 405,
#  'sim': 1491,
#  '##ion': 319,
#  '##ttie': 324,
#  'li': 451,
#  'sophie': 821,
#  'bla': 1429,
#  '##mund': 1066,
#  'nicholas': 1109,
#  '##ros': 1398,
#  'juanita': 1285,
#  'mon': 771,
#  'bern': 366,
#  '##ad': 1345,
#  '##ul': 602,
#  'augusta': 761,
#  'jonathan': 1247,
#  'ron': 952,
#  'gro': 1306,
#  'josh': 1427,
#  'norman': 800,
#  'roger': 1149,
#  'wilhelm': 389,
#  'vi': 606,
#  'jean': 356,
#  '##andr': 903,
#  'hel': 223,
#  'gertrude': 461,
#  'harris': 862,
#  'bell': 852,
#  '##des': 1000,
#  '##ert': 91,
#  'kar': 711,
#  'blan': 587,
#  '##or': 69,
#  '##tin': 338,
#  '##ide': 881,
#  'ole': 1314,
#  '##lo': 963,
#  '##orth': 1377,
#  '##pa': 1311,
#  'gertru': 364,
#  'stanley': 782,
#  'ella': 446,
#  'th': 120,
#  'luther': 841,
#  'juan': 314,
#  'franc': 136,
#  '##ob': 206,
#  '##ale': 763,
#  'emma': 250,
#  'bu': 1258,
#  'ag': 313,
#  'cyn': 1409,
#  '##mar': 998,
#  '##elle': 353,
#  'fa': 1362,
#  'bridg': 1456,
#  'cornelia': 1155,
#  '##ude': 452,
#  'ped': 607,
#  'bened': 1295,
#  'me': 1334,
#  'lucinda': 1167,
#  'stephan': 1442,
#  '##die': 466,
#  'const': 1203,
#  'petrus': 1382,
#  '##ony': 668,
#  '##dred': 443,
#  'chester': 815,
#  'franz': 887,
#  'simon': 964,
#  'gregor': 1132,
#  'jose': 99,
#  'johan': 537,
#  'francisco': 561,
#  '##el': 65,
#  '##hard': 836,
#  'maria': 113,
#  '##erson': 990,
#  'au': 1089,
#  '##tha': 170,
#  'tomas': 1169,
#  'fannie': 670,
#  'josepha': 1199,
#  '##eta': 760,
#  'kirstine': 1290,
#  'bett': 503,
#  '##eda': 1299,
#  'juli': 1335,
#  '##no': 1368,
#  'nel': 365,
#  '##vina': 762,
#  'elisabeth': 293,
#  'gottlieb': 1454,
#  'wilson': 977,
#  'hubert': 1090,
#  '##oph': 306,
#  'jens': 1141,
#  'louis': 172,
#  'richard': 278,
#  'mattie': 721,
#  'francis': 186,
#  'luise': 1342,
#  'manuel': 528,
#  'glenn': 891,
#  'the': 468,
#  'irvin': 1013,
#  '##mon': 259,
#  'steph': 592,
#  '##so': 1056,
#  'jeanette': 1256,
#  '##li': 60,
#  '##pe': 585,
#  '##ardo': 1462,
#  '##cott': 1330,
#  '##eb': 430,
#  'verna': 1404,
#  '##cy': 327,
#  '##ustin': 949,
#  'maude': 678,
#  'fr': 77,
#  'maur': 872,
#  '##lu': 1303,
#  'lucille': 709,
#  'ander': 1003,
#  'lou': 161,
#  'archib': 1451,
#  'alice': 240,
#  'arth': 242,
#  '##yl': 498,
#  'audrey': 1459,
#  '##tje': 1049,
#  'wilfred': 1532,
#  'oscar': 639,
#  'marg': 132,
#  'isabelle': 1174,
#  'willard': 923,
#  'regina': 1210,
#  'laur': 308,
#  'maxine': 1348,
#  '##omon': 1472,
#  'ter': 1034,
#  '##uel': 192,
#  'par': 1142,
#  'mart': 1282,
#  '##ant': 612,
#  'hendr': 1010,
#  'rafael': 1102,
#  'angela': 1284,
#  'iva': 1359,
#  'louise': 295,
#  'ruby': 641,
#  '##ael': 307,
#  'christine': 677,
#  'carolina': 1015,
#  '##ore': 420,
#  'pedro': 774,
#  '##elma': 548,
#  '##ner': 847,
#  'edith': 442,
#  'naomi': 1443,
#  'sue': 1475,
#  'rhoda': 1484,
#  'hu': 931,
#  'christopher': 1124,
#  'margarethe': 1496,
#  'sal': 459,
#  'pas': 1207,
#  '##men': 729,
#  '##lor': 1103,
#  'marc': 777,
#  'de': 368,
#  'el': 134,
#  'leonard': 552,
#  'betty': 577,
#  'ne': 732,
#  'lor': 394,
#  '##ana': 970,
#  'ar': 163,
#  'cecilia': 1263,
#  'delos': 1308,
#  'sylvester': 1319,
#  'bettie': 1380,
#  'roy': 438,
#  '##vieve': 1307,
#  'lorenzo': 1432,
#  'iv': 1528,
#  'gusta': 739,
#  't': 24,
#  'hans': 626,
#  'ann': 196,
#  '##ast': 1036,
#  '##ka': 1075,
#  '##an': 58,
#  'rich': 272,
#  'victor': 516,
#  'theodore': 662,
#  'harriet': 488,
#  'ca': 765,
#  'shirley': 940,
#  'feli': 559,
#  '##dis': 724,
#  'dom': 799,
#  'ser': 1339,
#  'eu': 973,
#  'bir': 1372,
#  'dar': 1437,
#  'mercedes': 1515,
#  'krist': 885,
#  'min': 317,
#  '##rich': 490,
#  'alma': 697,
#  'cl': 168,
#  'gr': 454,
#  'gre': 808,
#  'nathan': 818,
#  'jerry': 1241,
#  '##rik': 1529,
#  '##end': 1028,
#  'rebec': 572,
#  'phil': 661,
#  'herm': 926,
#  'manoel': 1184,
#  'rufus': 1213,
#  '##ura': 1220,
#  'lorra': 1356,
#  '##ite': 714,
#  '##ab': 106,
#  'joe': 687,
#  'stephen': 715,
#  'antonia': 751,
#  'kat': 813,
#  '##par': 1151,
#  '##abeth': 129,
#  'pie': 1337,
#  'genevieve': 1340,
#  '##idg': 1414,
#  'mol': 976,
#  'gold': 1304,
#  '##dr': 146,
#  'virg': 341,
#  '##ent': 423,
#  'pet': 248,
#  '##yn': 303,
#  'ray': 283,
#  'ph': 257,
#  'carrie': 567,
#  'pauline': 655,
#  'floyd': 706,
#  'pau': 237,
#  'eliza': 444,
#  '##dys': 546,
#  'juana': 704,
#  'ba': 768,
#  'ott': 779,
#  '##s': 41,
#  '##omas': 157,
#  '##illa': 647,
#  'louisa': 509,
#  '##at': 296,
#  'philipp': 995,
#  'willis': 1014,
#  'arnold': 1025,
#  '##sy': 1144,
#  'alph': 1173,
#  'lyn': 1216,
#  'margret': 1234,
#  '##helm': 362,
#  'wesley': 681,
#  'loretta': 1273,
#  '##ell': 203,
#  'gertrudis': 1358,
#  'alonzo': 1200,
#  'ab': 415,
#  'donald': 462,
#  'marianna': 1510,
#  'archie': 1211,
#  '##se': 82,
#  '##oma': 151,
#  'ol': 708,
#  'barbara': 408,
#  'silas': 1493,
#  '##ac': 145,
#  'gil': 781,
#  'vil': 1509,
#  'ra': 631,
#  'ross': 1336,
#  'st': 363,
#  '[MASK]': 4,
#  'wh': 1246,
#  'olive': 843,
#  'del': 326,
#  'jud': 1072,
#  '##ito': 1326,
#  'eunice': 1135,
#  'harrie': 959,
#  'lottie': 1128,
#  'h': 12,
#  'theresa': 825,
#  '##ly': 370,
#  'dejes': 1077,
#  'gen': 1357,
#  '##zel': 531,
#  '##ger': 776,
#  '##ryn': 999,
#  'aman': 676,
#  'cornelius': 1143,
#  'joannis': 1327,
#  '##oda': 1421,
#  'reub': 1226,
#  'gra': 342,
#  'friederich': 1162,
#  'soph': 402,
#  'wilhelmine': 954,
#  'bil': 1055,
#  'carm': 1498,
#  'sylv': 791,
#  'har': 141,
#  'mab': 393,
#  'ler': 665,
#  'ear': 1098,
#  'mark': 1181,
#  '##ptis': 1343,
#  '##rick': 500,
#  '##erva': 1426,
#  'le': 130,
#  '##lius': 638,
#  'ludwig': 1251,
#  '##elis': 1197,
#  '##iah': 651,
#  'cle': 555,
#  'nicola': 785,
#  '##erine': 208,
#  'amy': 1168,
#  'mich': 333,
#  '##en': 62,
#  'jo': 67,
#  '##ec': 287,
#  '##od': 298,
#  'flor': 275,
#  'fer': 543,
#  '##nes': 214,
#  'johanna': 604,
#  'gla': 517,
#  '##zo': 719,
#  '##iano': 974,
#  'rosina': 1146,
#  'myr': 455,
#  '##fug': 1338,
#  'lucile': 1350,
#  'lela': 1449,
#  'miguel': 1080,
#  '##etha': 487,
#  'arn': 899,
#  'virgil': 1115,
#  '##aria': 1305,
#  '##us': 89,
#  'hol': 1333,
#  'ja': 535,
#  '##ian': 184,
#  'j': 14,
#  'jacob': 284,
#  '##wig': 868,
#  'inez': 1159,
#  'bal': 1329,
#  'myrt': 522,
#  'sally': 1093,
#  'archibald': 1476,
#  'marguerite': 882,
#  'beatrice': 734,
#  'monroe': 1170,
#  '##bie': 993,
#  'vern': 745,
#  'isa': 569,
#  '##gen': 1467,
#  'ru': 195,
#  'amanda': 710,
#  'jakob': 680,
#  'rac': 673,
#  '##delia': 1164,
#  '##kin': 1420,
#  'anth': 692,
#  'lawrence': 549,
#  '##ica': 793,
#  '##atha': 1488,
#  'polly': 1375,
#  ...}

# %%
len(tokenizer.get_vocab())
# Out:
# 1536

# %% [markdown]
# ## Review sample

# %%
sample_size = 100
sample_df = counts_df.sample(sample_size)

# %%
for name in sample_df['alt_name']:
    print(name, tokenizer.encode(name).tokens)
# Out:
# friedezias ['frie', '##de', '##zia', '##s']
# eculaslica ['e', '##c', '##ula', '##s', '##li', '##ca']
# winberto ['win', '##bert', '##o']
# hylantha ['h', '##yl', '##ant', '##ha']
# melkadis ['mel', '##ka', '##dis']
# dorcenos ['dor', '##cen', '##os']
# stanrod ['stan', '##ro', '##d']
# hillyrd ['hil', '##ly', '##r', '##d']
# bionel ['b', '##ion', '##el']
# romarlo ['ro', '##mar', '##lo']
# johniyene ['john', '##i', '##y', '##ene']
# howlow ['ho', '##w', '##lo', '##w']
# fedillla ['f', '##ed', '##ill', '##la']
# amboleene ['amb', '##ol', '##ee', '##ne']
# felichian ['felic', '##h', '##ian']
# sydalia ['sy', '##dal', '##ia']
# grettke ['gre', '##tt', '##ke']
# arehy ['ar', '##e', '##h', '##y']
# hesckiak ['he', '##s', '##ck', '##ia', '##k']
# nielhi ['niel', '##h', '##i']
# hamernick ['ham', '##er', '##n', '##ick']
# foxcraft ['f', '##o', '##x', '##c', '##ra', '##f', '##t']
# vicentede ['vicente', '##de']
# skjerhold ['s', '##k', '##je', '##r', '##h', '##old']
# maurante ['maur', '##ant', '##e']
# buttermieer ['bu', '##tt', '##er', '##mie', '##er']
# celetonia ['ce', '##le', '##ton', '##ia']
# dasisse ['da', '##s', '##is', '##se']
# hornset ['ho', '##r', '##n', '##se', '##t']
# floricecq ['flor', '##ice', '##c', '##q']
# antomieta ['anto', '##mie', '##ta']
# wictoriana ['w', '##ic', '##tor', '##iana']
# rhett ['rh', '##ett']
# bantril ['ba', '##n', '##t', '##ri', '##l']
# ameranetta ['am', '##er', '##ane', '##tta']
# tarcisus ['t', '##ar', '##c', '##is', '##us']
# istdro ['is', '##t', '##dr', '##o']
# booteman ['b', '##oo', '##te', '##man']
# cadward ['ca', '##d', '##ward']
# alehaxande ['ale', '##ha', '##x', '##and', '##e']
# malfhada ['mal', '##f', '##ha', '##da']
# alcelirade ['al', '##ce', '##li', '##rad', '##e']
# deleyja ['del', '##ey', '##j', '##a']
# tofaatau ['t', '##of', '##a', '##at', '##a', '##u']
# sannby ['sa', '##n', '##n', '##by']
# bondemer ['b', '##on', '##de', '##mer']
# ellenortly ['ellen', '##or', '##t', '##ly']
# ludmillis ['lud', '##m', '##ill', '##is']
# koradrie ['k', '##ora', '##dr', '##ie']
# suterno ['s', '##u', '##ter', '##no']
# cadernow ['ca', '##der', '##no', '##w']
# zabadio ['z', '##ab', '##ad', '##io']
# nennetti ['ne', '##n', '##nett', '##i']
# machanty ['ma', '##ch', '##ant', '##y']
# maliali ['mal', '##ia', '##li']
# brintreet ['br', '##in', '##t', '##re', '##et']
# homeister ['ho', '##me', '##is', '##ter']
# geudasia ['ge', '##ud', '##as', '##ia']
# mildes ['mil', '##des']
# araloween ['ar', '##al', '##ow', '##ee', '##n']
# fennigin ['f', '##en', '##n', '##ig', '##in']
# heironzonus ['he', '##ir', '##onzo', '##n', '##us']
# stakeley ['st', '##a', '##ke', '##ley']
# antenetti ['an', '##te', '##nett', '##i']
# galiet ['g', '##al', '##ie', '##t']
# ametis ['am', '##et', '##is']
# adaheis ['ada', '##h', '##e', '##is']
# wundeling ['w', '##und', '##eli', '##n', '##g']
# forign ['for', '##ig', '##n']
# algarza ['al', '##gar', '##za']
# cwella ['c', '##well', '##a']
# ducillla ['du', '##c', '##ill', '##la']
# nigell ['n', '##ig', '##ell']
# karaelina ['kar', '##ael', '##ina']
# monisk ['mon', '##is', '##k']
# grounow ['gro', '##un', '##ow']
# elkes ['el', '##ke', '##s']
# lettillie ['le', '##tt', '##ill', '##ie']
# hagherleend ['ha', '##g', '##h', '##er', '##leen', '##d']
# kettlson ['ke', '##tt', '##l', '##son']
# geddin ['ge', '##d', '##din']
# abezeud ['ab', '##e', '##ze', '##ud']
# mocume ['mo', '##c', '##um', '##e']
# aucbiry ['au', '##c', '##b', '##ir', '##y']
# framellina ['fr', '##am', '##ell', '##ina']
# hadepa ['ha', '##de', '##pa']
# saintlio ['sa', '##in', '##t', '##lio']
# undritt ['u', '##n', '##dr', '##itt']
# messiu ['me', '##s', '##s', '##i', '##u']
# phawtara ['ph', '##a', '##w', '##ta', '##ra']
# wirguia ['w', '##irg', '##u', '##ia']
# hessir ['he', '##s', '##s', '##ir']
# copastrana ['co', '##pa', '##st', '##ra', '##na']
# emlrentie ['em', '##l', '##re', '##n', '##tie']
# svea ['s', '##ve', '##a']
# lavanderberg ['la', '##van', '##der', '##ber', '##g']
# dolhhis ['dol', '##h', '##h', '##is']
# arzeu ['ar', '##ze', '##u']
# yusfie ['y', '##us', '##f', '##ie']
# gradiglia ['gra', '##d', '##ig', '##lia']

# %% [markdown]
# ## Save tokenizers

# %%
save_file(tokenizer_path,
          lambda local_out_path : tokenizer.save(local_out_path))

# %% [markdown]
# ## Test load tokenizer

# %%
tokenizer_path
# Out:
# 's3://fs-nama-data/2024/nama-data/data/models/fs-given-subword-tokenizer-2048.json'

# %%
local_tokenizer_path = download_file_from_s3(tokenizer_path) if tokenizer_path.startswith("s3://") else tokenizer_path
loaded_tokenizer = PreTrainedTokenizerFast(tokenizer_file=local_tokenizer_path)

# %%
for name in ['chesworth', 'quass']:
    print(loaded_tokenizer.convert_ids_to_tokens(loaded_tokenizer.encode(name)))
# Out:
# ['ch', '##es', '##worth']
# ['qu', '##as', '##s']
